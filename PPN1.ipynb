# %% [markdown]
# # Conocimientos básicos sobre Electroencefalografía Superficial.
#
# **Materias relacionadas:** Medición y Análisis en la Física Experimental, Instrumentación y Calibración, Algoritmos Computacionales, Elaboración y Desarrollo de Proyectos Experimentales, Morfofuncional II, Instrumentación Biomédica, Electrofisiología y Temas Selectos de Biomatemáticas.
#
# ## EEG y sus bases fisiológicas.
#
# El EEG mide la actividad eléctrica de las células en la corteza cerebral. Es una representación de la diferencia de potencial entre dos regiones corticales cuando se trata de una adquisición bipolar y se grafica con respecto del tiempo. (Olejniczak,2006). En cambio con una derivación monopolar se registra la diferencia de potencial entre un electrodo activo colocado en el cuero cabelludo y un electrodo de referencia colocado en un punto neutro como el lóbulo de la oreja o el mastoides (Ramos-Argüelles, 2009)
#
#
# Para conocer la señal producida por los potenciales cerebrales es importante identificar el generador y los campos eléctricos que se generan. Las señales eléctricas se crean cuando las cargas eléctricas se mueven por el sistema nervioso central y para mantenerlas es necesaria la existencia de gradientes iónicos. (Olejniczak,2006; Hari,2017)
#
# 1. A nivel celular:
# La actividad que se capta en un EEG proviene principalmente de las neuronas que son células del sistema nerivoso que tienen interconexión por medio de impulsos eléctricos. Se genera una despolarización, que es un cambio en el potencial eléctrico de una célula excitable o grupo de células excitables donde el interior de la célula se vuelve menos negativo en relación con el exterior de la membrana.   El potencial de membrana en reposo de una neurona se da porque hay una salida de iones K+ que mantienen el equilibrio alrededor de -75mV. Cuando hay una depolarización hay un flujo de iones Na+ que excede el estado electroquímico normal de reposo. La apertura del canal en la membrana sucede gracias a un mecanismo dependiente de voltaje y el cierre depende del tiempo. La conducción a porciones vecinas a las membranas de las células nerviosas resultan en un potencial de acción. (Hari, 2017)
#
#
# Para que esta actividad sea detectada por el electrodo se necesita la suma de actividades de un gran número de neuronas, ya que no podemos medir los voltajes individualmente con este método. La señal que se obtiene en los electrodos se encuentra en el orden de microvolts, por lo que necesita ser amplificada.
#
# Los potenciales sinápticos son la fuente más importante para el registro extracelular. Los potenciales excitatorios postsinápticos (EPPs) fluyen hacia dentro de otras partes de la célula gracias a iones de sodio o de calcio. Los potenciales inhibitorios postsinápticos (IPPs) fluyen hacia afuera en dirección opuesta gracias a iones de cloro o de potasio. La suma de estos potenciales tienen una duración más larga que los potenciales de acción y dan las formas de onda característica del EEG.
#
# La conducción por volumen caracteriza el proceso de flujo de corriente entre el generador y el electrodo de registro. Las corteza cerebral es la principal fuente. Las células piramidales suelen ser las que más aportan a los potenciales registados por la forma en que están orientadas. Un volumen suficientemente grande para que pueda ser registrado por el electrodo necesita un área de entre 6 y 10 cm^2. Se necesitan estas áreas porque la piel, el cabello y el cráneo tienen un efecto atenuador.
#
# ## Características de la señal
# La señal de EEG presenta potenciales del orden del 10^-6 volts, por lo que supone un reto medir la actividad con dispositivos que suelen medir en el orden de volts, por lo que el sistema debe amplificar alrededor de un millón de veces la señal. Si se piensa en cómo se registraría eso, se necesita un sensor que reciba la información proveniente de las señales eléctricas del cerebro, este sensor es el electrodo. La señal obtenida va de los 0 a los 30 Hz. (Hari, 2017)
#
# Posteriormente, debe existir un dispositivo que registre la señal que está recibiendo el electrodo, en este caso sería el circuito básico del EEG, que contiene diversos circuitos de amplificación, para recibir la señal. Una vez recibida la señal, debe obtenerse la gráfica. (La Vaque, 1999)
#
# En los instrumentos modernos de EEG, se lleva a cabo una conversión analógica-digital. De esta forma se puede procesar la señal en la computadora, y cuando se quiere limpiar la señal pueden aplicarse distintos algoritmos y filtros para mejorar la resolución de la señal y eliminar artefactos.
#
# Las características generales de los electrodos para EEG deben ser:  pequeños, de metales no reactivos, con forma de copa colocados sobre el cuero cabelludo y con un pegamento conductivo (para evitar señales no deseadas). Entre los metales para su fabricación están: oro, plata, plata-cloruro de plata y platino, debe procurarse siempre el contacto óptimo para tener poca impedancia (Saptono, 2016). Se colocan en una gorra, diadema o directamente en electrodos que se ponen al paciente. En las siguientes figuras se observa la gorra con los electrodos y la posición de estos.
#
#
# |Tipo de onda|Rango de frecuencia|Localización|En estado fisiológico|
# |--|--|--|--|
# |Delta|1-4 Hz|En adolescentes y niños pequeños en la parte posterior de la cabeza.|Aparece durante el ritmo normal de sueño, y en uno de cada tres adultos puede apreciarse cuando se está despierto con los ojos abiertos|
# |Theta|4-8 Hz|Puede estar ausente, pero si se encuentra, está en la línea media y derivaciones temporales.|Marcada en niños pequeños. Somnolencia en adultos|
# |Alfa|8-13 Hz|Regiones frontocentrales pero también distribución amplia|Extracelular|
# |Beta|13-30 Hz|Regiones posteriores de la cabeza|Con los ojos abiertos, mientras se está relajado. La actividad es mayor en un lado dominante|
# |Gamma|>30 Hz|Distribución amplia pero principalmente centrales y temporales|Cognición|
#
# **Tabla 1.1** Tipos de onda, rangos de frecuencia, localización y cómo se manifiestan en estado fisiológico.
#
#
#
#
# ## Metodología para obtener una señal EEG
#
# Los datos utilizados en este notebook para visualizar las señales se obtuvieron del protocolo experimental "Electroencefalografía superficial en estado de reposo con ojos cerrados y ojos abiertos." en el que se registró una señal de EEG durante 3 minutos utilizando el sistema Emotiv EPOC+.
#
# Durante el tiempo de adquisición se dio la instrucción de abrir y cerrar los ojos de la siguiente manera:
#
#     a) 30 seg con ojos cerrados (tiempo de adaptación, segundo 0 a 30)
#     b) 30 seg con ojos cerrados (segundo 30 a 60)
#     c) 30 seg con ojos abiertos (segundo 60 a 90)
#     d) 15 seg con ojos cerrados (segundo 90 a 105)
#     e) 15 seg con ojos abiertos (segundo 105 a 120)
#     f) 15 seg con ojos cerrados (segundo 120 a 135)
#     g) 15 seg con ojos abiertos (segundo 135 a 150)
#     h) 30 seg con ojos cerrados (tiempo final del registro, segundo 150 a 180)
#
# Esto se realizó con la finalidad de observar las ondas alfa que se presentan durante el estado de reposo a ojos cerrados. Para consultar el protocolo completo se deja un enlace al protocolo: https://drive.google.com/file/d/1hFxnyBc10hX_tpzcPBGpA-LUESp9wiAC/view?usp=drive_link
#
# ## Preparando el entorno de Python para trabajar con los datos experimentales
# Teniendo el contexto de la fisiología de las señales podemos hacer un análisis sencillo en el que observemos cómo evoluciona temporalmente el voltaje de cada una. Debemos tomar en cuenta que estamos graficando valores de voltaje que corresponden a un valor en el tiempo, ambas son variables numéricas.
# A continuación se proveen enlaces para descargar las bibliotecas necesarias para abrir los datos, se trata de paquetes que incluyen funciones específicas para realizar cálculos, graficar, transformar los tipos de datos e incluso trabajar con formatos específicos de señales. Es importante que cuentes con ellas debido a que las usaremos a lo largo de los siete notebooks.
# Si ya cuentas con ellas omite esta parte; si no, ingresa al link que contenga la biblioteca que te hace falta.
#
#
#
#
# * Pandas:  Es una biblioteca que se desarrolló en 2008 (Rajagopalan, 2021). Se utiliza para el análisis econométrico de series de tiempo. Entre las características que resaltan están:
#     1. Provee indexación y etiquetado de datos
#     2. Permite leer archivos de distintas fuentes: Excel, CSV (del que hablaremos en el notebook 3) y JSON.
#     3. Visualización de datos reforzada en matplotlib
#     4. Comunicación con otras bibliotecas como matplotlib, scipy y numpy
#     5. Facilita la limpieza de datos.
#
#     Las instrucciones para descargarla podemos encontrarlas en el siguiente enlace: https://pandas.pydata.org/docs/getting_started/install.html
#
#
# * Numpy: Es una biblioteca de Python que se utiliza para cómputo matemático y procesar arreglos o colecciones. La configuración por default de Python procesa estructuras de datos de una dimensión. Los arreglos se vuelven una estructura fundamental pues pueden remodelar objetos y utilizan principios de vectorización de forma que si se aplica una operación a este objeto afecta a todos sus elementos (Rajagopalan, 2021). Las colecciones serán fundamentales en el desarrollo de los notebooks pues nos permiten realizar cálculos, operaciones y obtener gráficas.  Las instrucciones para descargar NumPy podemos encontrarlas en el siguiente enlace: https://numpy.org/install/
#
#
# * Matplotlib: Es una biblioteca que permite visualizar datos, principalmente permite la visualización en dos dimensiones (Rajagopalan, 2021), que para fines de esta serie de noteboks es suficiente. Con código podemos modificar distintos parámetros como: títulos, etiquetas, escala, tamaño de la figura y formato del texto de las gráficas. Las instrucciones de descarga e instalación se encuentran disponibles en: https://matplotlib.org/stable/users/installing/index.html
#
# * Scipy: es una biblioteca para cómputo científico y cómputo matemático (Rajagopalan, 2021). Contiene una serie de algoritmos de distintas disciplinas entre las que rescataremos cálculo, matrices y análisis de señales. Contiene distintos submódulos. Las instrucciones para instalarlas las obtenemos en el siguiente enlace: https://scipy.org/install/

# %%
import numpy as np
import matplotlib.pyplot as plt
## %matplotlib inline 
## %config InlineBackend.figure_formats = {'png', 'retina'}
import pandas as pd
import os.path as os
from scipy import*

# %%
carpeta = os.abspath('/Users/yann/Documents/Datos/EEG/') #localización del 
#archivo en tu computadora
datos = pd.read_csv(carpeta +'/H24_OC_OA.csv') #creación de un dataframe
#al que únicamente debes modificar el nombre del archivo con su extensión
datos #comando para presentar el dataframe
# Out:
#        EEG.AF3   EEG.F7   EEG.F3  EEG.FC5   EEG.T7   EEG.P7   EEG.O1   EEG.O2  \
# 0      4339.49  4521.03  4187.69  4627.69  4339.49  4112.31  4348.72  4252.31
# 1      4346.67  4527.18  4202.05  4633.85  4342.05  4122.05  4366.67  4267.69
# 2      4350.26  4540.00  4207.18  4643.08  4341.54  4122.05  4374.87  4271.28
# 3      4337.95  4530.77  4198.46  4638.46  4336.92  4118.97  4372.31  4258.97
# 4      4334.87  4519.49  4189.23  4629.23  4342.05  4118.97  4369.74  4245.64
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 23122  4414.87  4522.05  4201.54  4683.08  4384.62  4105.64  4361.54  4217.44
# 23123  4413.85  4524.10  4200.51  4685.64  4388.72  4106.15  4349.74  4196.92
# 23124  4416.41  4523.08  4204.62  4690.26  4391.28  4102.05  4337.44  4183.59
# 23125  4413.85  4520.51  4205.13  4687.69  4383.08  4094.36  4336.41  4183.59
# 23126  4409.74  4518.97  4201.03  4683.08  4377.95  4096.92  4352.31  4192.31
#
# ...

# %% [markdown]
# Son valores en voltaje. No necesariamente calibrados pero se encuentran en el rango de microVolts. Para nuestros objetivos no importa tener el valor exactamente calibrado. El análisis va hacia frecuencia porque no estamos analizando amplitud absoluta.

# %% [markdown]
# ## Observando los datos sin procesar
# Observamos un resumen de los datos crudos que arroja el equipo emotiv EPOC. Al abrir el archivo tenemos la señal de catorce electrodos que se colocaron a los participantes, en este caso tenemos la visualización de un sólo sujeto. Podemos observar que tenemos 23094 columnas que corresponden al valor de voltaje registrado obtenido con una frecuencia de muestreo de 128 datos por segundo para tener aproximadamente 3 minutos de datos. Cada una de las catorce columnas nos da el nombre del electrodo y con el arreglo se puede observar la posición de cada electrodo.
#
# Para propósitos de esta parte del material, vamos a trabajar en cómo se extrae el archivo y cómo graficar para distintos tiempos. En el notebook 2 veremos que es importante realizar un proceso de filtrado para dar sentido fisiológico a los datos.
#
# Corrobora el tiempo de adquisición del protocolo con el siguiente ejercicio.
# * Obten el número de filas del dataframe utilizando una función len
# * Divídelo por la frecuencia de muestreo
# * Finalmente almacénalo en una variable llamada "t_adq"
# * ¿En qué unidades estará tu resultado?
#
# Modifica el código presentado en la celda para obtener tu resultado

# %%
#Ejercicio
freqm= __
t_adq= __
print('El tiempo de adquisición fue de '+ str(t_adq)  + ' segundos')
# Out:
# El tiempo de adquisición fue de  segundos

# %%
#Solución
freqm= 128
t_adq= len(datos)/freqm
print('El tiempo de adquisición fue de '+ str(t_adq)  + ' segundos')
# Out:
# El tiempo de adquisición fue de 180.6796875 segundos

# %% [markdown]
# ## Primer abordaje para observar los datos en el dominio del tiempo.
# A continuación se presenta un código con el que podemos visualizar los valores de cada electrodo en el rango de 0 a 180 segundos.

# %%
fm=128 #frecuencia de muestreo
ti=0 #tiempo de inicio, debe ser número entero
tf=180 #tiempo final, debe ser número entero
pt=(tf-ti)*fm#numero de puntos
t1=ti*fm #nos ayuda a dar la posición de la fila para el tiempo inicial
t2=tf*fm #nos ayuda a dar la posición de la fila para el tiempo final
nombres=list(datos) #almacena los nombres de los encabezados en una lista
t=np.linspace(ti,tf,pt) 
for i in range (0,14):
    plt.figure(figsize=(12,3))
    plt.plot(t,np.array(datos)[t1:t2,i])
    plt.title(nombres[i]) #itera sobre el nombre de las columnas para dar título a los gráficos
    plt.xlabel('tiempo'+' [s]')
    plt.show()

# %% [markdown]
# Si quisieras obtener una vista en un rango diferente de tiempo, por ejemplo para ver por separado los intervalos de tiempo del protocolo tendrías que modificar algunas variables en el código. Inténtalo en una celda de código.
# * ¿Qué variables se modificaron?
# Esta forma de visualizar los datos no nos permite apreciar algunas características de la señal y tampoco podemos ver la escala de 30 segundos que es relevante para el protocolo.
# * ¿Por qué esta forma de visualizar es poco práctica?
# * ¿Cómo podrías mejorarla?
#
# ## Mejorando la visualización
# Una solución es visualizar en un sólo panel que contenga las señales de los 14 electrodos, además de modificar el tamaño de las figuras. Nuestras herramientas serán:
# * Convertir las columnas del dataframe en arreglos.
# * Almacenar los nombres de los electrodos en una lista para iterar sobre ella y usar los nombres para etiquetar el eje Y en vez de usar los nombres como título superior de cada gráfica.
# * Hacer un panel con los 14 electrodos haciendo subplots valiéndonos de un ciclo for.

# %%
##Abierto
fm=128 #frecuencia de muestreo
ti_c=105 #tiempo de inicio, debe ser número entero
tf_c=120 #tiempo final, debe ser número entero
pt_c=(tf_c-ti_c)*fm#numero de puntos
t1_c=ti_c*fm #nos ayuda a dar la posición de la fila para el tiempo inicial
t2_c=tf_c*fm #nos ayuda a dar la posición de la fila para el tiempo final
nombres=list(datos) #almacena los nombres de los encabezados en una lista
t_c=np.linspace(ti_c,tf_c,pt_c) 
escala_c=1
rg_c=int(tf_c/escala_c)
for i in range (0,14):
    plt.figure(figsize=(15,12))
    plt.subplot(14,1,i+1) #(filas, columnas, i)
    plt.xticks([escala_c*j for j in range(rg_c+1)])
    plt.plot(t_c,np.array(datos)[t1_c:t2_c,i]) #t tiempo, i posición
    plt.ylabel(nombres[i])#itera sobre el nombre de las columnas para dar título a los gráficos
    if i == 13:  # Si es el último subplot
        plt.xlabel('Tiempo [s]')  # Agregar la etiqueta al eje x
    plt.show()
# Etiquetar tiempo en la última línea del subplot

# %%
##Cerrado
fm=128 #frecuencia de muestreo
ti_a=120 #tiempo de inicio, debe ser número entero
tf_a=135 #tiempo final, debe ser número entero
pt_a=(tf_a-ti_a)*fm#numero de puntos
t1_a=ti_a*fm #nos ayuda a dar la posición de la fila para el tiempo inicial
t2_a=tf_a*fm #nos ayuda a dar la posición de la fila para el tiempo final
nombres=list(datos) #almacena los nombres de los encabezados en una lista
t_a=np.linspace(ti_a,tf_a,pt_a) 
escala_a=1
rg_a=int(tf_a/escala_a)
for i in range (0,14):
    plt.figure(figsize=(15,12))
    plt.subplot(14,1,i+1) #(filas, columnas, i)
    plt.xticks([escala_a*j for j in range(rg_a+1)])
    plt.plot(t_a,np.array(datos)[t1_a:t2_a,i]) #t tiempo, i posición
    plt.ylabel(nombres[i])#itera sobre el nombre de las columnas para dar título a los gráficos
    if i == 13:  # Si es el último subplot
        plt.xlabel('Tiempo [s]')  # Agregar la etiqueta al eje x
    plt.show()

# %% [markdown]
# * ¿Cómo mejoró esta visualización con respecto a la anterior?
# * ¿En qué parte del código se cambió el tamaño?
# * ¿Puedes identificar en qué partes del código se incluye la modificación de la escala?
# * ¿Cómo modificarías el código para observar los primeros 5 canales? (Recuerda que Python comienza contando en 0)
# * ¿Qué necesitas hacer si quieres visualizar algún canal en específico?
#
# ¿Qué columnas de datos corresponden a los occipitales?
# ¿Cómo los graficarías?

# %%
#Graficando un solo canal
plt.figure(figsize=(10,4)) #tamaño de la figura
plt.ylabel(nombres[6])
plt.title('Actividad de 105 a 120 segundos en ojos abiertos')
plt.xlabel('Tiempo [s]')
plt.plot(t_c,np.array(datos)[t1_c:t2_c,6])
plt.ylim(4320,4420)
# Out:
# (4320.0, 4420.0)

# %%
#Solución completa
plt.figure(figsize=(15,12)) #tamaño de la figura
plt.subplot(4, 1, 3)
plt.ylabel(nombres[6])
plt.title('Actividad de 120 a 135 segundos en ojos cerrados')
plt.plot(t_a,np.array(datos)[t1_a:t2_a,6])
plt.subplot(4, 1, 4)
plt.ylabel(nombres[7])
plt.title('Actividad de 120 a 135 segundos en ojos cerrados')
plt.plot(t_a,np.array(datos)[t1_a:t2_a,7])
plt.xlabel("Tiempo [s]")
#Durante ojos cerrados
plt.subplot(4, 1, 1)
plt.ylabel(nombres[6])
plt.title('Actividad de 105 a 120 segundos en abiertos')
plt.plot(t_c,np.array(datos)[t1_c:t2_c,6])
plt.subplot(4, 1, 2)
plt.ylabel(nombres[7])
plt.title('Actividad de 105 a 120 segundos en ojos abiertos')
plt.plot(t_c,np.array(datos)[t1_c:t2_c,7])
plt.tight_layout() #comando para brindar espacio entre subplots
plt.show()

# %% [markdown]
# ## Artefactos en la señal
# En el análisis de señales de electroencefalograma (EEG), es común encontrar ruido y artefactos que pueden dificultar la interpretación de los datos. Los artefactos son señales no deseadas que no son generadas por la actividad cerebral, sino que provienen de fuentes externas o internas al paciente. Estos artefactos pueden enmascarar o distorsionar la información relevante sobre la actividad cerebral, lo que complica el análisis y la interpretación de los resultados (Luck, 2014).
#
# En el siguiente notebook veremos cómo corregir algunos de dichos artefactos. Es relevante primero hacer una inspección visual para identificar el patrón temporal de dónde se genera dicho ruido.
#
# ### Artefactos fisiológicos:
# Estos artefactos son generados por el propio paciente y pueden clasificarse en varias categorías según su origen:
#
# * Oculares: Los movimientos oculares, como abrir y cerrar los ojos, parpadear o mover los ojos, generan potenciales eléctricos que se propagan a través del cuero cabelludo. Estos potenciales, conocidos como artefactos oculares, son causados por el movimiento del dipolo córneo-retinal, que produce cambios en el campo eléctrico registrado por los electrodos (Niedermeyer & da Silva, 2005).
#
# * Actividad muscular facial: Las contracciones musculares, especialmente en la cara y el cuero cabelludo, pueden generar artefactos musculares. Estos artefactos suelen ser de alta frecuencia y pueden superponerse a las señales cerebrales, dificultando su identificación (Fatourechi et al., 2007).
#
# * Cardiacos: Los artefactos cardiacos, como los pulsos eléctricos generados por el latido del corazón, también pueden aparecer en los registros de EEG. Estos artefactos son causados por la actividad eléctrica del corazón y pueden ser identificados por su patrón rítmico y sincronizado con el pulso (Sörnmo & Laguna, 2005).
#
# ### Artefactos no fisiológicos
# Los artefactos no fisiológicos son causados por factores externos al paciente, como problemas técnicos o interferencias ambientales. Estos incluyen:
# ### Artefactos de línea eléctrica:
#
# * Interferencia de 50/60 Hz: La interferencia de la red eléctrica es uno de los artefactos más comunes en EEG. Se manifiesta como una señal de alta frecuencia (50 Hz o 60 Hz, dependiendo de la región) y puede ser causada por un mal aislamiento de los cables o una mala conexión a tierra (Niedermeyer & da Silva, 2005).
#
# * Artefactos de movimiento:
#
# * Movimiento del paciente: Los movimientos bruscos del paciente, como estirarse o cambiar de posición, pueden generar artefactos de alta amplitud en todos los canales.
#
# * Vibraciones externas: Las vibraciones del entorno, como las causadas por equipos mecánicos, también pueden afectar la señal de EEG.
#
# * Mala colocación de electrodos: Si los electrodos no están bien colocados o hacen mal contacto con el cuero cabelludo, pueden generar artefactos de alta amplitud.
#
# * Desplazamiento de electrodos: El movimiento de los electrodos durante la grabación puede causar artefactos de alta frecuencia.
#
# * Cables sueltos o dañados: Los cables sueltos o dañados pueden introducir ruido en la señal de EEG.
#
# * Interferencia electromagnética: Fuentes externas de interferencia electromagnética, como equipos electrónicos cercanos, pueden generar artefactos en la señal.

# %% [markdown]
# ## Referencias
# - EMOTIV EPOC+ 14-channel wireless EEG headset. (2016, February 3). EMOTIV. https://www.emotiv.com/epoc/
# - Fatourechi, M., Bashashati, A., Ward, R. K., & Birch, G. E. (2007). EMG and EOG artifacts in brain computer interface systems: A survey. *Clinical Neurophysiology, 118*(3), 480-494. https://doi.org/10.1016/j.clinph.2006.10.019
# - Hari, R., & Puce, A. (2017). *MEG-EEG Primer*. Oxford University Press.
# - Installation. (n.d.). Scipy.org. Retrieved August 4, 2023, from https://scipy.org/install/
# - Installation — matplotlib 3.7.2 documentation. (n.d.). Matplotlib.org. Retrieved August 4, 2023, from https://matplotlib.org/stable/users/installing/index.html
# - Installation — pandas 2.0.3 documentation. (n.d.). Pydata.org. Retrieved August 4, 2023, from https://pandas.pydata.org/docs/getting_started/install.html
# - Installing NumPy. (n.d.). Numpy.org. Retrieved August 4, 2023, from https://numpy.org/install/
# - Jung, T. P., Makeig, S., Humphries, C., Lee, T. W., McKeown, M. J., Iragui, V., & Sejnowski, T. J. (2000). Removing electroencephalographic artifacts by blind source separation. *Psychophysiology, 37*(2), 163-178. https://doi.org/10.1111/1469-8986.3720163
# - Kaya, I. (2019). A brief summary of EEG artifact handling. *Brain-computer interface, (9)*.
# - Luck, S. J. (2014). *An introduction to the event-related potential technique* (2nd ed.). MIT Press.
# - Niedermeyer, E., & da Silva, F. L. (2005). *Electroencephalography: Basic principles, clinical applications, and related fields* (5th ed.). Lippincott Williams & Wilkins.
# - La Vaque, T. J. (1999). The history of EEG Hans Berger: Psychophysiologist. A historical vignette. *Journal of Neurotherapy, 3*(2), 1-9.
# - Olejniczak, P. (2006). Neurophysiologic basis of EEG. *Journal of Clinical Neurophysiology, 23*(3), 186-189.
# - Rajagopalan, G. (2021). *A Python Data Analyst's Toolkit: Learn Python and Python-based Libraries with Applications in Data Analysis and Statistics*.
# - Ramos-Argüelles, F., Morales, G., Egozcue, S., Pabón, R. M., & Alonso, M. T. (2009). Técnicas básicas de electroencefalografía: principios y aplicaciones clínicas. In *Anales del sistema sanitario de Navarra* (Vol. 32, pp. 69-82). Gobierno de Navarra. Departamento de Salud.
# - Saptono, D., Wahyudi, B., & Irawan, B. (2016). Design of EEG signal acquisition system using Arduino MEGA1280 and EEGAnalyzer. In *MATEC Web of Conferences* (Vol. 75, p. 04003). EDP Sciences.
# - Sörnmo, L., & Laguna, P. (2005). *Bioelectrical signal processing in cardiac and neurological applications*. Academic Press.
# - Sazgar, M., Young, M. G., Sazgar, M., & Young, M. G. (2019). EEG artifacts. In *Absolute Epilepsy and EEG Rotation Review: Essentials for Trainees* (pp. 149-162).
